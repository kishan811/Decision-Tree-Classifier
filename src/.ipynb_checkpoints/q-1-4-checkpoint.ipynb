# %%
import numpy as np
from math import log
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import random
from pprint import pprint
from itertools import zip_longest

# %%
df = pd.read_csv("../input_data/train1.csv")
train_df, test_df = train_test_split(df, test_size=0.2)
grph = sns.FacetGrid(data=train_df, hue="left", aspect=2, height=7)
grph.map(plt.scatter,'satisfaction_level','number_project').add_legend()
grph.fig.suptitle('2-D plot of 2 attributes')
# Out:
# Text(0.5, 0.98, '2-D plot of 2 attributes')
